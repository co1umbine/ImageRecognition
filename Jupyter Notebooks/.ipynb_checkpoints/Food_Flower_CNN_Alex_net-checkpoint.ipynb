# %% [markdown]
# # 畳み込みニューラルネット
# ## インポート

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.autograd import Variable
import torch.nn.functional as F
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
from PIL import Image
import time
import os
import cv2
from sklearn.model_selection import KFold

print(torch.cuda.is_available())
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# Out:
# True

# %% [markdown]
# ## 変数、クラス定義

# %%
directory_path = "D:/Work/ImageRecognition/Images/%s"
food_path = "food_142/"
flower_path = "flower_142/"
food_test_path = "food_test/"
flower_test_path = "flower_test/"
num_classes = 2

#画像の前処理を定義
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),  # ランダムにトリミングして (224, 224)の形状にしてる
        transforms.RandomHorizontalFlip(),  # 50%の確率で水平方向に反転させる
        transforms.ToTensor(),  # Tensorに変換
        transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])  # 平均値と標準偏差を指定して、結果のTensorを正規化
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),  # 画像のサイズを(256, 256)にする
        transforms.CenterCrop(224),  # (224, 224)にするために、サイズ変更された画像を中央で切り取る
        transforms.ToTensor(),  # Tensorに変換
        transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])  # 平均値と標準偏差を指定して、結果のTensorを正規化
    ]),
}
#正規化をしない前処理
to_tensor_transforms = transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor()
    ])

def cross_validate(net, split_size=5):
  results = []
  fold = KFold(n_splits=3, shuffle=True, random_state=0)
  for train_idx, val_idx in kf.split(train_x_all, train_y_all):
    train_x = train_x_all[train_idx]
    train_y = train_y_all[train_idx]
    val_x = train_x_all[val_idx]
    val_y = train_y_all[val_idx]
    run_train(session, train_x, train_y)
    results.append(session.run(accuracy, feed_dict={x: val_x, y: val_y}))
  return results

class FoodFlowerDataset(torch.utils.data.Dataset):

    def __init__(self, transform=None, train=True):
        self.transform = transform
        self.images = []
        self.labels = []
        if train:
            food_folder = directory_path%(food_path)
            flower_folder = directory_path%(flower_path)
        else:
            food_folder = directory_path%(food_test_path)
            flower_folder = directory_path%(flower_test_path)
        self.images.extend([food_folder + p for p in os.listdir(food_folder)])
        self.labels.extend([0] * len(self.images))
        self.images.extend([flower_folder + p for p in os.listdir(flower_folder)])
        self.labels.extend([1] * (len(self.images)-len(self.labels)))
        
    def __getitem__(self, index):
        image = self.images[index]
        label = self.labels[index]
        with open(image, "rb") as f:
            image = Image.open(f)
            image = image.convert("RGB")
        if self.transform is not None:
            image = self.transform(image)
        return image, label
        
    def __len__(self):
        return len(self.images)


class AlexNet(nn.Module):
    #fc_sizeを引き渡す
    def __init__(self, num_classes):
        super(AlexNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )
        size_check = torch.FloatTensor(10, 3, 224, 224)
        fc_size = self.features(size_check).view(size_check.size(0), -1).size()[1]
        #fc_sizeで計算した形状を指定
        self.classifier = nn.Sequential(
            nn.Dropout(p=0.5),
            nn.Linear(fc_size, 4096), 
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Linear(4096, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

# %% [markdown]
# ## AlexNet Adam

# %%
net = AlexNet(num_classes).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.0001)

num_epochs = 200

# %%
train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

# 定義したDatasetとDataLoaderを使用
train_dataset = FoodFlowerDataset(data_transforms["train"], train=True)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=10, 
                                           shuffle=True)
valuation_dataset = FoodFlowerDataset(data_transforms["val"], train=False)
valuation_loader = torch.utils.data.DataLoader(dataset=valuation_dataset,
                                           batch_size=5, 
                                           shuffle=False)

for epoch in range(num_epochs):
    train_loss = 0
    train_acc = 0
    val_loss = 0
    val_acc = 0
    
    net.train()
    for i, (images, labels) in enumerate(train_loader):
      images, labels = images.to(device), labels.to(device)
      
      optimizer.zero_grad()
      outputs = net(images)
      loss = criterion(outputs, labels)
      train_loss += loss.item()
      train_acc += (outputs.max(1)[1] == labels).sum().item()
      loss.backward()
      optimizer.step()

    avg_train_loss = train_loss / len(train_loader.dataset)
    avg_train_acc = train_acc / len(train_loader.dataset)

    net.eval()
    with torch.no_grad():
      for images, labels in valuation_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        loss = criterion(outputs, labels)
        val_loss += loss.item()
        val_acc += (outputs.max(1)[1] == labels).sum().item()
    avg_val_loss = val_loss / len(valuation_loader.dataset)
    avg_val_acc = val_acc / len(valuation_loader.dataset)

    print ('Epoch [{}/{}], Loss: {loss:.4f}, val_loss: {val_loss:.4f}, val_acc: {val_acc:.4f}' 
                   .format(epoch+1, num_epochs, i+1, loss=avg_train_loss, val_loss=avg_val_loss, val_acc=avg_val_acc))
    train_loss_list.append(avg_train_loss)
    train_acc_list.append(avg_train_acc)
    val_loss_list.append(avg_val_loss)
    val_acc_list.append(avg_val_acc)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure()
plt.plot(range(num_epochs), train_loss_list, color='blue', linestyle='-', label='train_loss')
plt.plot(range(num_epochs), val_loss_list, color='green', linestyle='--', label='val_loss')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Training and validation loss')
plt.grid()

plt.figure()
plt.plot(range(num_epochs), train_acc_list, color='blue', linestyle='-', label='train_acc')
plt.plot(range(num_epochs), val_acc_list, color='green', linestyle='--', label='val_acc')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('acc')
plt.title('Training and validation accuracy')
plt.grid()
# Out:
# Epoch [1/200], Loss: 0.0694, val_loss: 0.1414, val_acc: 0.7059
# Epoch [2/200], Loss: 0.0711, val_loss: 0.1793, val_acc: 0.5735
# Epoch [3/200], Loss: 0.0638, val_loss: 0.1118, val_acc: 0.7500
# Epoch [4/200], Loss: 0.0581, val_loss: 0.1177, val_acc: 0.6324
# Epoch [5/200], Loss: 0.0532, val_loss: 0.1023, val_acc: 0.7794
# Epoch [6/200], Loss: 0.0495, val_loss: 0.0867, val_acc: 0.7794
# Epoch [7/200], Loss: 0.0443, val_loss: 0.0981, val_acc: 0.7941
# Epoch [8/200], Loss: 0.0439, val_loss: 0.0956, val_acc: 0.8235
# Epoch [9/200], Loss: 0.0453, val_loss: 0.0865, val_acc: 0.8088
# Epoch [10/200], Loss: 0.0433, val_loss: 0.0883, val_acc: 0.7353
# Epoch [11/200], Loss: 0.0364, val_loss: 0.0735, val_acc: 0.8529
# Epoch [12/200], Loss: 0.0370, val_loss: 0.0691, val_acc: 0.8382
# Epoch [13/200], Loss: 0.0333, val_loss: 0.0958, val_acc: 0.8088
# Epoch [14/200], Loss: 0.0376, val_loss: 0.0827, val_acc: 0.8088
# Epoch [15/200], Loss: 0.0296, val_loss: 0.0991, val_acc: 0.7941
# Epoch [16/200], Loss: 0.0286, val_loss: 0.0680, val_acc: 0.8676
# Epoch [17/200], Loss: 0.0252, val_loss: 0.0758, val_acc: 0.8382
# Epoch [18/200], Loss: 0.0302, val_loss: 0.0984, val_acc: 0.8235
# Epoch [19/200], Loss: 0.0399, val_loss: 0.0719, val_acc: 0.8529
# Epoch [20/200], Loss: 0.0233, val_loss: 0.0787, val_acc: 0.8676
# Epoch [21/200], Loss: 0.0248, val_loss: 0.0730, val_acc: 0.8235
# Epoch [22/200], Loss: 0.0267, val_loss: 0.0673, val_acc: 0.8824
# Epoch [174/200], Loss: 0.0117, val_loss: 0.0663, val_acc: 0.8971
# Epoch [175/200], Loss: 0.0050, val_loss: 0.0626, val_acc: 0.9118
# Epoch [176/200], Loss: 0.0116, val_loss: 0.0720, val_acc: 0.8824
# Epoch [177/200], Loss: 0.0056, val_loss: 0.0981, val_acc: 0.8529
# Epoch [178/200], Loss: 0.0104, val_loss: 0.0822, val_acc: 0.8824
# Epoch [179/200], Loss: 0.0043, val_loss: 0.0745, val_acc: 0.8676
# Epoch [180/200], Loss: 0.0059, val_loss: 0.0604, val_acc: 0.9118
# Epoch [181/200], Loss: 0.0073, val_loss: 0.0695, val_acc: 0.8824
# Epoch [182/200], Loss: 0.0056, val_loss: 0.0604, val_acc: 0.9265
# Epoch [183/200], Loss: 0.0112, val_loss: 0.0833, val_acc: 0.8824
# Epoch [184/200], Loss: 0.0100, val_loss: 0.1069, val_acc: 0.8088
# Epoch [185/200], Loss: 0.0077, val_loss: 0.0617, val_acc: 0.9118
# Epoch [186/200], Loss: 0.0042, val_loss: 0.0494, val_acc: 0.8971
# Epoch [187/200], Loss: 0.0044, val_loss: 0.0688, val_acc: 0.8676
# Epoch [188/200], Loss: 0.0127, val_loss: 0.1015, val_acc: 0.8529
# Epoch [189/200], Loss: 0.0048, val_loss: 0.0552, val_acc: 0.8971
# Epoch [190/200], Loss: 0.0036, val_loss: 0.0949, val_acc: 0.8971
# Epoch [191/200], Loss: 0.0073, val_loss: 0.0734, val_acc: 0.8235
# Epoch [192/200], Loss: 0.0051, val_loss: 0.1354, val_acc: 0.8676
# Epoch [193/200], Loss: 0.0062, val_loss: 0.0996, val_acc: 0.8676
# Epoch [194/200], Loss: 0.0046, val_loss: 0.0826, val_acc: 0.9265
# Epoch [195/200], Loss: 0.0048, val_loss: 0.0721, val_acc: 0.8824
# Epoch [196/200], Loss: 0.0024, val_loss: 0.1462, val_acc: 0.8676
# Epoch [197/200], Loss: 0.0097, val_loss: 0.1115, val_acc: 0.8529
# Epoch [198/200], Loss: 0.0084, val_loss: 0.0867, val_acc: 0.8676
# Epoch [199/200], Loss: 0.0048, val_loss: 0.0875, val_acc: 0.8824
# Epoch [200/200], Loss: 0.0045, val_loss: 0.1042, val_acc: 0.8676

# %% [markdown]
# ## AlexNet SGD

# %%
net = AlexNet(num_classes).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9, weight_decay=5e-4)

num_epochs = 200

# %%
train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

# 定義したDatasetとDataLoaderを使用
train_dataset = FoodFlowerDataset(data_transforms["train"], train=True)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=10, 
                                           shuffle=True)
valuation_dataset = FoodFlowerDataset(data_transforms["val"], train=False)
valuation_loader = torch.utils.data.DataLoader(dataset=valuation_dataset,
                                           batch_size=5, 
                                           shuffle=False)

for epoch in range(num_epochs):
    train_loss = 0
    train_acc = 0
    val_loss = 0
    val_acc = 0
    
    net.train()
    for i, (images, labels) in enumerate(train_loader):
      images, labels = images.to(device), labels.to(device)
      
      optimizer.zero_grad()
      outputs = net(images)
      loss = criterion(outputs, labels)
      train_loss += loss.item()
      train_acc += (outputs.max(1)[1] == labels).sum().item()
      loss.backward()
      optimizer.step()

    avg_train_loss = train_loss / len(train_loader.dataset)
    avg_train_acc = train_acc / len(train_loader.dataset)

    net.eval()
    with torch.no_grad():
      for images, labels in valuation_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        loss = criterion(outputs, labels)
        val_loss += loss.item()
        val_acc += (outputs.max(1)[1] == labels).sum().item()
    avg_val_loss = val_loss / len(valuation_loader.dataset)
    avg_val_acc = val_acc / len(valuation_loader.dataset)

    print ('Epoch [{}/{}], Loss: {loss:.4f}, val_loss: {val_loss:.4f}, val_acc: {val_acc:.4f}' 
                   .format(epoch+1, num_epochs, i+1, loss=avg_train_loss, val_loss=avg_val_loss, val_acc=avg_val_acc))
    train_loss_list.append(avg_train_loss)
    train_acc_list.append(avg_train_acc)
    val_loss_list.append(avg_val_loss)
    val_acc_list.append(avg_val_acc)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure()
plt.plot(range(num_epochs), train_loss_list, color='blue', linestyle='-', label='train_loss')
plt.plot(range(num_epochs), val_loss_list, color='green', linestyle='--', label='val_loss')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Training and validation loss')
plt.grid()

plt.figure()
plt.plot(range(num_epochs), train_acc_list, color='blue', linestyle='-', label='train_acc')
plt.plot(range(num_epochs), val_acc_list, color='green', linestyle='--', label='val_acc')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('acc')
plt.title('Training and validation accuracy')
plt.grid()
# Out:
# Epoch [1/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [2/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [3/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [4/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [5/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [6/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [7/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [8/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [9/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [10/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [11/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [12/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [13/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [14/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [15/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [16/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [17/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [18/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [19/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [20/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [21/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [22/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [23/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [24/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [25/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [26/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [27/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [28/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [29/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [30/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [31/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [32/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [33/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [34/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [35/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [36/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [37/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [38/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [39/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [40/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [41/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [42/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [43/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [44/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [45/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [46/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [47/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [48/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [49/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [50/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [51/200], Loss: 0.0693, val_loss: 0.1428, val_acc: 0.4706
# Epoch [52/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [53/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [54/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [55/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [56/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [57/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [58/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [59/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [60/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [61/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [62/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [63/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [64/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [65/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [66/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [67/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [68/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [69/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [70/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [71/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [72/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [73/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [74/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [75/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [76/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [77/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [78/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [79/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [80/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [81/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [82/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [83/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [84/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [85/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [86/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [87/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [88/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [89/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [90/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [91/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [92/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [93/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [94/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [95/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [96/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [97/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [98/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [99/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [100/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [101/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [102/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [103/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [104/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [105/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [106/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [107/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [108/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [109/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [110/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [111/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [112/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [113/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [114/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [115/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [116/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [117/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [118/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [119/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [120/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [121/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [122/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [123/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [124/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [125/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [126/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [127/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [128/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [129/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [130/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [131/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [132/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [133/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [134/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [135/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [136/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [137/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [138/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [139/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [140/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [141/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [142/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [143/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [144/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [145/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [146/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [147/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [148/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [149/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [150/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [151/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [152/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [153/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [154/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [155/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [156/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [157/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [158/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [159/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [160/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [161/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [162/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [163/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [164/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [165/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [166/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [167/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [168/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [169/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [170/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [171/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [172/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [173/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [174/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [175/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [176/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [177/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [178/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [179/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [180/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4706
# Epoch [181/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4853
# Epoch [182/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4853
# Epoch [183/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4853
# Epoch [184/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4853
# Epoch [185/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4853
# Epoch [186/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4853
# Epoch [187/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4853
# Epoch [188/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4853
# Epoch [189/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4853
# Epoch [190/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4853
# Epoch [191/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4853
# Epoch [192/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4853
# Epoch [193/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4853
# Epoch [194/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.4853
# Epoch [195/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.5000
# Epoch [196/200], Loss: 0.0692, val_loss: 0.1427, val_acc: 0.5000
# Epoch [197/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.5000
# Epoch [198/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.5000
# Epoch [199/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.5000
# Epoch [200/200], Loss: 0.0693, val_loss: 0.1427, val_acc: 0.5000
